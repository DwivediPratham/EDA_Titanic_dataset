# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#univariate analysis

# %% [markdown]
# Age
# conclusion-
#
# ```
# Age is normally distributed
# 19 percent missing data
# ```

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.kdeplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# 0.19865319865319866

# %% [markdown]
# **Fare**

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.kdeplot(df['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df[df['Fare']>300]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Survived'>

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Pclass'>

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Sex'>

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['SibSp'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='SibSp'>

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df['Parch'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Parch'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Parch'>

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Embarked'>

# %% [markdown]
# **Bivariate Analysis**

# %%
pd.crosstab(df['Survived'],df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df['Survived'],df['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Sex'],normalize='columns')*100)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
pd.crosstab(df['Survived'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Embarked'],normalize='columns')*100)
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %%
pd.crosstab(df['Sex'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df['Pclass'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# **Numerical and categorical analysis**

# %%
df[df['Survived']==1]['Age'].plot(kind='kde') #survived
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['Survived']==0]['Age'].plot(kind='kde') #not survived
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['Survived']==1]['Age'].plot(kind='kde',label='survived') #survived
df[df['Survived']==0]['Age'].plot(kind='kde',label='Not survived') #not survived
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[df['Survived']==1]['Age'].plot(kind='box') #survived
# Out:
# <Axes: >

# %%
df[df['Survived']==0]['Age'].plot(kind='box') #not survived
# Out:
# <Axes: >

# %% [markdown]
# **Feature Engineering**

# %%
#creating a new column for individual fares
df[df['SibSp']==8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df['Ticket'].value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
df1=pd.read_csv('/content/test.csv')

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df=pd.concat([df,df1])

# %%
df['Ticket'].value_counts()
# Out:
# CA. 2343        11
# CA 2144          8
# 1601             8
# PC 17608         7
# S.O.C. 14879     7
#                 ..
# 113792           1
# 36209            1
# 323592           1
# 315089           1
# 359309           1
# Name: Ticket, Length: 929, dtype: int64

# %%
df['individual_fare']=df['Fare']/(df['SibSp']+df['Parch']+1) # Individual fare

# %%
# creating a new column Family size
df['family_size']=df['SibSp']+df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Creating family_type from family_size
#
# *   1-> Alone
# *   2-4-> small
# *   greater than 5-> large

# %%
def family_transform(num):
  if num==1:
    return "Alone"
  elif num>1 and num<5:
    return 'Small'
  else:
    return 'Large'

# %%
df['family_type']=df['family_size'].apply(family_transform)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df['Survived'],df['family_type'],normalize='columns')*100
# Out:
# family_type      Alone      Large      Small
# Survived
# 0.0          44.720497  70.890411  43.150685
# 1.0          55.279503  29.109589  56.849315

# %%
df['Sirname']=df['Name'].str.split(',').str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['title']=df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['title'] = df['title'].str.replace('Rev.','other')
df['title'] = df['title'].str.replace('Dr.','other')
df['title'] = df['title'].str.replace('Col.','other')
df['title'] = df['title'].str.replace('Major.','other')
df['title'] = df['title'].str.replace('Capt.','other')
df['title'] = df['title'].str.replace('the','other')
df['title'] = df['title'].str.replace('Jonkheer.','other')
# ,'Dr.','Col.','Major.','Don.','Capt.','the','Jonkheer.']
# Out:
# <ipython-input-81-ffb23deeff2c>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Rev.','other')
# <ipython-input-81-ffb23deeff2c>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Dr.','other')
# <ipython-input-81-ffb23deeff2c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Col.','other')
# <ipython-input-81-ffb23deeff2c>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Major.','other')
# <ipython-input-81-ffb23deeff2c>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Capt.','other')
# ...

# %%
temp_df = df[df['title'].isin(['Mr.','Miss.','Mrs.','Master.','ootherr'])]

# %%
pd.crosstab(temp_df['Survived'],temp_df['title'],normalize='columns')*100
# Out:
# title     Master.     Miss.        Mr.  Mrs.    ootherr
# Survived
# 0.0          42.5  30.21978  84.332689  20.8  72.222222
# 1.0          57.5  69.78022  15.667311  79.2  27.777778

# %%
df['Cabin'].isnull().sum()
# Out:
# 1014

# %%
df['Cabin'].fillna('M',inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# M                  1014
# C23 C25 C27           6
# B57 B59 B63 B66       5
# G6                    5
# F33                   4
#                    ...
# A14                   1
# E63                   1
# E12                   1
# E38                   1
# C105                  1
# Name: Cabin, Length: 187, dtype: int64

# %%
df['deck']=df['Cabin'].str[0]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['deck'].value_counts()
# Out:
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: deck, dtype: int64

# %%
pd.crosstab(df['deck'],df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df['Survived'],df['deck'],normalize='columns')*100
# Out:
# deck              A          B          C          D     E          F     G  \
# Survived
# 0.0       53.333333  25.531915  40.677966  24.242424  25.0  38.461538  50.0
# 1.0       46.666667  74.468085  59.322034  75.757576  75.0  61.538462  50.0
#
# deck              M      T
# Survived
# 0.0       70.014556  100.0
# 1.0       29.985444    0.0

# %%
pd.crosstab(df['deck'],df['Survived'],normalize='index').plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='deck'>
